# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import box

# %%
#kasumigaura = gpd.read_file(
    #"/home/rushikesh/PhD/Global_Lakes/Shape_Files/Lake_Kasumigaura.shp")
#Tohoe = gpd.read_file("/home/rushikesh/PhD/Global_Lakes/Shape_Files/Lake_Tohoe/shapefile/Lake_Tahoe.shp")
Dal = gpd.read_file("/home/rushikesh/PhD/Progress_Presentation_6/Dal_Lake.shp")

# %%
print(type(Dal))
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>

# %%
fig, ax = plt.subplots(figsize=(14, 6))

# %%
#kasumigaura.plot()
#Tohoe.plot()
#plt.title('Lake Kasumigaura')
Dal.plot()
#plt.title('Lake Tohoe')
plt.title('Dal Lake')
plt.xlabel('Long')
plt.ylabel('Lat')
plt.grid(True)

#plt.savefig('/home/rushikesh/PhD/Global_Lakes/Shape_Files/Lake_Kasumigaura.pdf')
#plt.savefig('/home/rushikesh/PhD/Global_Lakes/Shape_Files/Lake_Tohoe_Shp.pdf')
plt.savefig('/home/rushikesh/PhD/Global_Lakes/Shape_Files/Dal_Lake_Shp.pdf')
plt.show()

# %%
plt.text?
